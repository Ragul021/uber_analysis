# %% [markdown]
# # uber project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uber_df=pd.read_csv('uberdrive.csv')
uber_df[:-1]
uber_df.shape
uber_df.info()
uber_df.size
uber_df.columns # display all columns
uber_df.columns[0] 
list(uber_df.columns) # display columns in list
uber_df.dtypes # display the data type of the columns 
uber_df.select_dtypes(include=['float']) # to select particular datatype
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 uber_dv=pd.read_csv('uberdrive.csv')
#       2 uber_dv[:-1]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'uberdrive.csv'

# %% [markdown]
# # data preprocessing

# %%
uber_df['purpose'].fillnaa('not',inplace=True)
uber_df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 uber_df['purpose'].fillnaa('not',inplace=True)
#       2 uber_df.isnull().sum()
#
# NameError: name 'uber_df' is not defined

# %% [markdown]
# # chech duplicate

# %%
uber_df.duplicated() # gives boolean value
uber_df[uber_df.duplicated()] # gives the duplicated rows
uber_df.drop_duplicates(inplace=True) # to remove the duplpicate 
uber_df.describe() # for numerical 
uber_df.describe(include=['object']) # for categorical value 
uber_df.describe(include=all) # to diplay both
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 uber_df.duplicated() # gives boolean value
#       2 uber_df[uber_df.duplicated()] # gives the duplicated rows
#       3 uber_df.drop_duplicates(inplace=True) # to remove the duplpicate
#
# NameError: name 'uber_df' is not defined

# %% [markdown]
# # converting datatype one to another

# %%
uber_df['start_date']=pd.to_datetime(uber_df['start_date'],errors='coerce')
uber_df['end_date']=pd.to_datetime(uber_df['end_date'],errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 uber_df['start_date']=pd.to_datetime(uber_df['start_date'],errors='coerce')
#       2 uber_df['end_date']=pd.to_datetime(uber_df['end_date'],errors='coerce')
#
# NameError: name 'uber_df' is not defined

# %% [markdown]
# # to get only the date and only time

# %%
from datetime import datetime 
uber_df['date']=pd.DatetimwIndex(uber_df['start_date']).date
uber_df['']=pd.DatetimwIndex(uber_df['start_date']).hour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 from datetime import datetime
# ----> 2 uber_df['date']=pd.DatetimwIndex(uber_df['start_date']).date
#       3 uber_df['']=pd.DatetimwIndex(uber_df['start_date']).hour
#
# AttributeError: module 'pandas' has no attribute 'DatetimwIndex'

# %% [markdown]
# # splitting the time

# %%
uber_df['day-night']=pd.cut(data=uber_df,x=time,bins=[0,10,15,19,24],labels=['morning','afternoon','evening','night'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 uber_df['day-night']=pd.cut(data=uber_df,x=time,bins=[0,10,15,19,24],labels=['morning','afternoon','evening','night'])
#
# NameError: name 'uber_df' is not defined

# %% [markdown]
# # data visualization

# %%
plt.figure(figsize(10,4))
sns.histplot(df['miles'],bins=20,kde=True,color='blue',edgecolor='black',alpha=0.7)
plt.xlabel('miles')
plt.ylabel('frequency')
plt.title('Distrinution of miles')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.figure(figsize(10,4))
#       2 sns.histplot(df['miles'],bins=20,kde=True,color='blue',edgecolor='black',alpha=0.7)
#       3 plt.xlabel('miles')
#
# NameError: name 'figsize' is not defined

# %%
print(uber_df['start'].unique()) 
print(uber_df['start'].nunique())
print(uber_df['stop'].unique()) 
print(uber_df['stop'].nunique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(uber_df['start'].unique())
#       2 print(uber_df['start'].nunique())
#       3 print(uber_df['stop'].unique())
#
# NameError: name 'uber_df' is not defined

# %%
uber_df['start'].value_count().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 uber_df['start'].value_count().head()
#
# NameError: name 'uber_df' is not defined

# %%
pd.value_count(uber_df['start'].iloc[:10]) # get first 10 value in start column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.value_count(uber_df['start'].iloc[:10]) # get first 10 value in start column
#
# NameError: name 'pd' is not defined

# %%
sns.countplot(y=start,data=uber_df,order=pd.value_count(uber_df['start'].iloc[:10]),palette='viridis'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.countplot(y=start,data=uber_df,order=pd.value_count(uber_df['start'].iloc[:10]))
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # how to avoid warning

# %%
import warnings
warnings.filterwarnings('ignore') # all the warning are ignored 
warnings.filterwarnings('ignore',
                        message='hello'
                        lineno=21
                        module='module_name'
                        category='category_name') # warning with the word hello will be ignored
# Out:
#   Cell In[4], line 4
#     message='hello'
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
plt.figure(figsize(10,5))
plt.countplot(data=uber_df,x='category',hue='day-night',palette='set2')
plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.figure(figsize(10,5))
#       2 plt.countplot(data=uber_df,x='category',hue='day-night',palette='set2')
#       3 plt.xticks(rotation=90)
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize(10,5))
plt.histplot(data=uber_df,x='category',,multiple='stack',hue='day-night',palette='set2')
plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('')
plt.show()
# gives the output in histplot and in stacked manner
# Out:
#   Cell In[6], line 2
#     plt.histplot(data=uber_df,x='category',,multiple='stack',hue='day-night',palette='set2')
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # for normalizing and proposition

# %%
plt.figure(figsize(10,5))
sns.histplot(data=uber_df,x='category',
             multiple='fill',
             stat='probability',
             common_norm=False, # normalize each category wise if normalize=True it will normalize whole category 
             hue='day-night',
             palette='set2')
plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.figure(figsize(10,5))
#       2 sns.histplot(data=uber_df,x='category',
#       3              multiple='fill',
#       4              stat='probability',
#       5              common_norm=False, # normalize each category wise if normalize=True it will normalize whole category
#       6              hue='day-night',
#       7              palette='set2')
#       8 plt.xticks(rotation=90)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # heatmap

# %%
plt.figure(figsize(10,6))
heat_map=(uber_df.groupby(['purpose','day-night']).size() #or
heat_map=pd.crosstab(uber_df['purpose'],uber_df['day-night'],normalizze='index')
sns.heatmap(heat_map,annot=True,cmap='YlGnBu',fmt='d')# annot is used to diaplay the value and fmt is used to convert into integer
plt.show()
# Out:
#   Cell In[1], line 2
#     heat_map=(uber_df.groupby(['purpose','day-night']).size() #or
#              ^
# SyntaxError: '(' was never closed

# %% [markdown]
# # pie chart

# %%
plt.figure(figsize(8,8))
uber_df('category'),value_count(),plot.pie(startangle=90,cmap='Set3',autopct='$1.1f%%')
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure(figsize(8,8))
#       2 uber_df('category'),value_count(),plot.pie(startangle=90,cmap='Set3',autopct='$1.1f%%')
#       3 plt.ylabel('')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # pie chart using erxplode

# %%
plt.figure(figsize(8,8))
explode=(0.1 if cat=='business' else 0 ,for cat in uber_df['category'].value_count().index)
uber_df('category'),value_count(),plot.pie(startangle=90,cmap='Set3',autopct='$1.1f%%',explodde=explode)
plt.ylabel('')
plt.show()

# %% [markdown]
# # pie chart using legends

# %%
plt.figure(figsize(8,8))
uber_df('category'),value_count(),plot.pie(startangle=90,cmap='Set3',autopct='None',labels='None')
plt.legends(labels=uber_df['category'].value_counts().indes,loc='upper right')
plt.ylabel('')
plt.show()

# %% [markdown]
# # pie chart to display both percentage and value

# %%
plt.figure(figsize(8,8))
def auto_value(pct,value):
    total=sum(value)
    absolute=int(pct/100.*total)
    return (f'{pct:.1f}%/n{absolute}')
uber_df('category').value_count(),plot.pie(startangle=90,cmap='Set3',autopct=lambda pct : auto_pct(pct,uber_df['category'].value_count()))

plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure(figsize(8,8))
#       2 def auto_value(pct,value):
#       3     total=sum(value)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # box plot

# %%
plt.figure(figsize(10,8))
sns.boxplot(data=uber_df,x='day-night',
            y='miles',
            hue='category',
            palette='coolwarm',
            showfliers=True,
            fliersize=3)# showfiler is used to show the outlier and the size is used to make the outlier size bigger
plt.yscale('log') # for clear view
plt.xlabel('day-night')
plt.ylabel('miles')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.figure(figsize(10,8))
#       2 sns.boxplot(data=uber_df,x='day-night',y='miles',palette='coolwarm')
#       3 plt.xlabel('day-night')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # swramplot

# %%
plt.figure(figsize(10,8))
sns.boxplot(data=uber_df,x='day-night',y='miles',hue='category',palette='coolwarm')
sns.boxplot(data=uber_df,x='day-night',y='miles',size=3,color='black')
plt.xlabel('day-night')
plt.ylabel('miles')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.figure(figsize(10,8))
#       2 sns.boxplot(data=uber_df,x='day-night',y='miles',hue='category',palette='coolwarm')
#       3 sns.boxplot(data=uber_df,x='day-night',y='miles',size=3,color='black')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # facegrid

# %%
g=sns.faceGrid(uber_data,col='category',height=6,aspect=1.5)# if we use aspect ,aspect=width*height i.e 6*1.5
g.map(sns.boxplot,'day-night','miles',palette='coolwarm')
g.set_axis_label('day-night','miles')
g.suptitle('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 g=sns.faceGrid(uber_data,col='category',height=6,aspect=1.5)# if we use aspect ,aspect=width*height i.e 6*1.5
#       2 g.map(sns.boxplot,'day-night','miles',palette='coolwarm')
#       3 g.set_axis_label('day-night','miles')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # violin plot

# %%
plt.figure(figsize(10,5))
sns.violinplot(data=uber_df,x='purpose',y='miles',palette='coolwarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.figure(figsize(10,5))
#       2 sns.violinplot(data=uber_df,x='purpose',y='miles',palette='coolwarm')
#       3 plt.xticks(rotation=90)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # using whitegrid for background change

# %%
sns.set(style='whitegrid') # background will be white 
plt.figure(figsize(10,5))
sns.violinplot(data=uber_df,x='purpose',y='miles',hue='category',palette='coolwarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.set(style='whitegrid')
#       2 plt.figure(figsize(10,5))
#       3 sns.violinplot(data=uber_df,x='purpose',y='miles',palette='coolwarm')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # box plot inside violin plot

# %%
sns.set(style='whitegrid') # background will be white 
plt.figure(figsize(10,5))
sns.violinplot(data=uber_df,x='purpose',y='miles',inner='box',scale='width',palette='coolwarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.set(style='whitegrid') # background will be white
#       2 plt.figure(figsize(10,5))
#       3 sns.violinplot(data=uber_df,x='purpose',y='miles',inner='box',palette='coolwarm')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # bar plot

# %%
plt.figure(figsize(10,6))
sns.barplot(data=uber_df,x='purpose',y='miles',estimator=np.mean,ci=None,palette='set3')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.figure(figsize(10,6))
#       2 sns.barplot(data=uber_df,x='purpose',y='miles',estimator=sum,ci=None,palette='set3')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # sorting in barplot

# %%
plt.figure(figsize(10,6))
order=uber_df('purpose')['miles'].sum().sort_values(ascending=False).index
sns.barplot(data=uber_df,x='purpose',y='miles',estimator=sum,order=order,palette='set3')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.figure(figsize(10,6))
#       2 order=uber_df('purpose')['miles'].sum().sort_values(ascending=False).index
#       3 sns.barplot(data=uber_df,x='purpose',y='miles',estimator=sum,order=order,palette='set3')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # annotation function

# %%
plt.figure(figsize(10,6))
#order=uber_df('purpose')['miles'].sum().sort_values(ascending=False).index
ax=sns.barplot(data=uber_df,x='purpose',y='miles',estimator=sum,order=order,palette='set3')
for p in ax.patches:
    p.annotate(f'{p.get_height():.1f}',(p.get_x()+p.get_width()/2.,p.get_height())
               ,ha='center',va='center',xytext=(0,9),textcoords='offset points')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.figure(figsize(10,6))
#       2 #order=uber_df('purpose')['miles'].sum().sort_values(ascending=False).index
#       3 ax=sns.barplot(data=uber_df,x='purpose',y='miles',estimator=sum,order=order,palette='set3')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # scatterplot

# %%
plt.figure(figsize(10,8))
sns.scatterplot(data=uber_df,x='miles',y='personal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize(10,8))
#       2 sns.scatterplot(data=uber_df,x='miles',y='personal')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # regplot

# %%
plt.figure(figsize(10,8))
sns.regplot(data=uber_df,x='miles',y='personal',scatter_kws={'s':10},line_kws={'color':'red'})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.figure(figsize(10,8))
#       2 sns.regplot(data=uber_df,x='miles',y='personal',scatter_kws={'s':10},line_kws={'color':'red'})
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
g=sns.facegrid(uber_df,col='category',height=4,aspect=1.5)
g.map(sns.scatterplot,'time','miles')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 g=sns.facegrid(uber_df,col='category',height=4,aspect=1.5)
#       2 g.map(sns.scatterplot,'time','miles')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # stripplot

# %%
plt.figure(figsize(10,8))
sns.stripplot(data=uber_df,x='miles',y='personal',jitter=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.figure(figsize(10,8))
#       2 sns.stripplot(data=uber_df,x='miles',y='personal',jitter=True)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
def round(x):
    if['start']==['stop']:
        return yes
    else:
        return no
uber_df['round']=uber_df.apply(round,axis=1)
sns.countplot(uber_df['round'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4     else:
#       5         return no
# ----> 6 uber_df['round']=uber_df.apply(round,axis=1)
#       7 sns.countplot(uber_df['round'])
#       8 plt.show()
#
# NameError: name 'uber_df' is not defined

# %%
uber_df['month']=pd.DatetimeIndex(uber_df['start_date']).month
uber_df['month']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 uber_df['month']=pd.DatetimeIndex(uber_df['start_date']).month
#       2 uber_df['month']
#
# NameError: name 'pd' is not defined

# %%
dict={1:'jan',2:'feb':,3:'mar',4:'apr'}
uber_df['month'].map(dict)
# Out:
#   Cell In[2], line 1
#     dict={1:'jan',2:'feb':,3:'mar',4:'apr'}
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # minute calculation lineplot

# %%
uber_df['minutes']=uber_df['end_date']-uber_df['start_date']
sns.lineplot(data=uber_df,
             x='minutes'.dt.total_seconds()/60,
             y='miles') #dt.total_seconds()/60 converts seconds into mminute
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 uber_df['minutes']=uber_df['end_date']-uber_df['start_date']
#       2 sns.lineplot(data=uber_df,x='minutes',y='miles')
#
# NameError: name 'uber_df' is not defined

# %%
pd.Dataframe({'min':groupby(['purpose'])['miles'].min(),
              'mean':groupby(['purpose'])['miles'].mean()
              'max':groupby(['purpose'])['miles'].max()})
# Out:
#   Cell In[7], line 2
#     'mean':groupby(['purpose'])('miles').mean()
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pd.set_option('display.max_rows',None) # to display all rows 
pd.set_option('display.max_columns',None)# to display all columns
pd.set_option('display.max_colwidth',200) # to incerase the width size to display all the letter
pd.set_option('display.float_format','{:.2f}'.format) # to add 2 decimal to all the integer
pd.set_option('display.precision',3) # round off 
pd.set_option('display.expand_frame_repr',False)
pd.set_option('display.large_repr','info')
uber_df.groupby(['month']['purpose'])('round_trip').count()
# Out:
# <>:2: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.set('display.max_rows',None)
#       2 uber_df.groupby(['month']['purpose'])('round_trip').count()
#
# NameError: name 'pd' is not defined

# %%
data={f'column_{i}':list(range(500))for i in range(10)}
pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 data={f'column_{i}':list(range(500))for i in range(10)}
# ----> 2 pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
pd.reset_option('display.large_repr')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.reset_option('display.large_repr')
#
# NameError: name 'pd' is not defined

# %%
uber_df['days']=uber_df['start_date'].dt.day_name()
plt.figure(figsize(10,6))
sns.countplot(data=uber_df,x='days',order=['mon','tue','wed','thu','fri','sat','sun'))
plt.show()

# %%
round_trip=uber_df['round'].value_counts()
round_trip.plot(kind=pie,autopct='%1.1f%%',startangle=90,color=coolwarm
# Out:
#   Cell In[2], line 2
#     round_trip.plot(kind=pie,autopct='%1.1f%%',startangle=90,color=coolwarm
#                                                                            ^
# _IncompleteInputError: incomplete input

# %%
uber_df['top']=uber_df['start'].value_counts().head(10)
ax=sns.countplot(data=uber_df,x='top')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}',(p.get_x()+p.get_width()/2.p.get_height(),va='center',ha='center')
                
    
plt.show()
# Out:
#   Cell In[1], line 4
#     ax.annotate(f'{p.get_height()}',(p.get_x()+p.get_width()/2.p.get_height(),va='center',ha='center')
#                                                               ^
# SyntaxError: invalid decimal literal

# %%
sns.countplot(data=uber_df,x='times')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.countplot(data=uber_df,x='times')
#
# NameError: name 'sns' is not defined

# %%
uber_df.columns.str.replace('*','',regex=False).str.replace(' ','').str.lower(),str.strip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 uber_df.columns.str.replace('*','',regex=False).str.replace(' ','').str.lower(),str.strip()
#
# NameError: name 'uber_df' is not defined

# %%
uber_df['weeekday']=uber_df['start'].dt.day_name()
hello=uber_df.groupby('weekday').size()
avg=hello/uber_df['weekday'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 uber_df['weeekday']=uber_df['start'].dt.day_name()
#       2 hello=uber_df.groupby('weekday').size()
#       3 avg=hello/uber_df['weekday'].nunique()
#
# NameError: name 'uber_df' is not defined

# %%
uber_df(uber_df['round']=='yes'.group_by('start').size().sort_values(ascending=False).head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 uber_df['round']=='yes'.group_by('start').size().sort_values(ascending=False).head(5)
#
# NameError: name 'uber_df' is not defined

# %%
uber_df.group_by('day-night')['miles'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 uber_df.group_by('day-night')['miles'].mean()
#
# NameError: name 'uber_df' is not defined

# %%
same_location=uber_df[uber_df['start']==uber_df['stop']]
num_same_location=same_location.shape[0]
average_miles=same_location['miles'].mean()
